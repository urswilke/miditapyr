# %%
from music21 import *

# %%
import pandas
import numpy as np

# %%
mid = converter.parse('/home/chief/Bitwig Studio/Projects/bossa_raw/midi_arpeggiated.mid')
mid.show()

# %%
# %run '../py/py_funs.py'
a = music21_midi_df(mid)
a
# Out:
#       index  i_track                                              event  \
# 0         0        1  <music21.tempo.MetronomeMark allegretto Quarte...
# 1         1        1                  <music21.meter.TimeSignature 4/4>
# 2         2        1     [<music21.note.Note C>, <music21.note.Note D>]
# 3         3        1                           <music21.note.Rest rest>
# 4         4        1                            [<music21.note.Note D>]
# ...     ...      ...                                                ...
# 2589   1267        3                           [<music21.note.Note F#>]
# 2590   1268        3                           [<music21.note.Note C#>]
# 2591   1269        3                           [<music21.note.Note F#>]
# 2592   1270        3                           [<music21.note.Note C#>]
# 2593   1271        3                           [<music21.note.Note F#>]
#
#        meta   rest     notes   pitches pitch_classes    vel          name  \
# ...

# %%
# df2 = df.loc[df['event'].apply(lambda x: isinstance(x, chord.Chord))]
# df2['note'] = [list(i.pitches) for i in c if isinstance(i, chord.Chord)]
# df2['offset'] = [i.offset for i in c if isinstance(i, chord.Chord)]
# df2['duration'] = [i.duration for i in c if isinstance(i, chord.Chord)]

# df2
